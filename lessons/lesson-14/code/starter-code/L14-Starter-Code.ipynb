# %%
# Unicode Handling
from __future__ import unicode_literals
import codecs

import numpy as np
import gensim

# spacy is used for pre-processing and traditional NLP
import spacy
from spacy.en import English

# Gensim is used for LDA and word2vec
from gensim.models.word2vec import Word2Vec

# %%
# Unicode Handling
from __future__ import unicode_literals

import pandas as pd
import json

data = pd.read_csv("../../../lesson-13/code/dataset/stumbleupon.tsv", sep='\t',
                  encoding="utf-8")
data['title'] = data.boilerplate.map(lambda x: json.loads(x).get('title', ''))
data['body'] = data.boilerplate.map(lambda x: json.loads(x).get('body', ''))
data.head()
# Out:
#                                                  url  urlid  \
# 0  http://www.bloomberg.com/news/2010-12-23/ibm-p...   4042
# 1  http://www.popsci.com/technology/article/2012-...   8471
# 2  http://www.menshealth.com/health/flu-fighting-...   1164
# 3  http://www.dumblittleman.com/2007/12/10-foolpr...   6684
# 4  http://bleacherreport.com/articles/1205138-the...   9006
#
#                                          boilerplate alchemy_category  \
# 0  {"title":"IBM Sees Holographic Calls Air Breat...         business
# 1  {"title":"The Fully Electronic Futuristic Star...       recreation
# 2  {"title":"Fruits that Fight the Flu fruits tha...           health
# 3  {"title":"10 Foolproof Tips for Better Sleep "...           health
# 4  {"title":"The 50 Coolest Jerseys You Didn t Kn...           sports
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.789131     2.055556           0.676471           0.205882
# 1               0.574147     3.677966           0.508021           0.288770
# 2               0.996526     2.382883           0.562016           0.321705
# 3               0.801248     1.543103           0.400000           0.100000
# 4               0.719157     2.676471           0.500000           0.222222
#
#    commonlinkratio_3  commonlinkratio_4  \
# 0           0.047059           0.023529
# 1           0.213904           0.144385
# 2           0.120155           0.042636
# 3           0.016667           0.000000
# 4           0.123457           0.043210
#
#                          ...                          linkwordscore  \
# 0                        ...                                     24
# 1                        ...                                     40
# 2                        ...                                     55
# 3                        ...                                     24
# 4                        ...                                     14
#
#    news_front_page  non_markup_alphanum_characters  numberOfLinks  \
# 0                0                            5424            170
# 1                0                            4973            187
# 2                0                            2240            258
# 3                0                            2737            120
# 4                0                           12032            162
#
#    numwords_in_url  parametrizedLinkRatio  spelling_errors_ratio label  \
# 0                8               0.152941               0.079130     0
# 1                9               0.181818               0.125448     1
# 2               11               0.166667               0.057613     1
# 3                5               0.041667               0.100858     1
# 4               10               0.098765               0.082569     0
#
#                                                title  \
# 0  IBM Sees Holographic Calls Air Breathing Batte...
# 1  The Fully Electronic Futuristic Starting Gun T...
# 2  Fruits that Fight the Flu fruits that fight th...
# 3                10 Foolproof Tips for Better Sleep
# 4  The 50 Coolest Jerseys You Didn t Know Existed...
#
#                                                 body
# 0  A sign stands outside the International Busine...
# 1  And that can be carried on a plane without the...
# 2  Apples The most popular source of antioxidants...
# 3  There was a period in my life when I had a lot...
# 4  Jersey sales is a curious business Whether you...
#
# [5 rows x 29 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

bodies = data['body'].dropna().copy()
vectorizer=CountVectorizer(max_features=1000, binary=False, stop_words="english")

# %%
X = vectorizer.fit_transform(bodies)

# %%
id2word = dict(enumerate(vectorizer.get_feature_names()))

# %%
id2word
# Out:
# {0: '00',
#  1: '000',
#  2: '08',
#  3: '09',
#  4: '10',
#  5: '100',
#  6: '11',
#  7: '12',
#  8: '13',
#  9: '14',
#  10: '15',
#  11: '16',
#  12: '17',
#  13: '18',
#  14: '19',
#  15: '20',
#  16: '2005',
#  17: '2006',
#  18: '2007',
#  19: '2008',
#  20: '2009',
#  21: '2010',
#  22: '2011',
#  23: '2012',
#  24: '21',
#  25: '22',
#  26: '23',
#  27: '24',
#  28: '25',
#  29: '26',
#  30: '27',
#  31: '28',
#  32: '29',
#  33: '30',
#  34: '31',
#  35: '35',
#  36: '350',
#  37: '40',
#  38: '45',
#  39: '50',
#  40: '60',
#  41: 'ability',
#  42: 'able',
#  43: 'according',
#  44: 'actually',
#  45: 'ad',
#  46: 'add',
#  47: 'added',
#  48: 'adding',
#  49: 'addition',
#  50: 'additional',
#  51: 'age',
#  52: 'ago',
#  53: 'air',
#  54: 'alcohol',
#  55: 'allow',
#  56: 'amazing',
#  57: 'america',
#  58: 'american',
#  59: 'app',
#  60: 'apple',
#  61: 'apples',
#  62: 'april',
#  63: 'area',
#  64: 'aren',
#  65: 'art',
#  66: 'article',
#  67: 'aside',
#  68: 'ask',
#  69: 'asked',
#  70: 'athletes',
#  71: 'attention',
#  72: 'august',
#  73: 'author',
#  74: 'available',
#  75: 'average',
#  76: 'avocado',
#  77: 'avoid',
#  78: 'away',
#  79: 'awesome',
#  80: 'baby',
#  81: 'background',
#  82: 'bacon',
#  83: 'bad',
#  84: 'bag',
#  85: 'bake',
#  86: 'baked',
#  87: 'baking',
#  88: 'ball',
#  89: 'balls',
#  90: 'banana',
#  91: 'bar',
#  92: 'bars',
#  93: 'base',
#  94: 'based',
#  95: 'basic',
#  96: 'basil',
#  97: 'batter',
#  98: 'bean',
#  99: 'beans',
#  100: 'beat',
#  101: 'beautiful',
#  102: 'beauty',
#  103: 'beef',
#  104: 'beer',
#  105: 'begin',
#  106: 'believe',
#  107: 'benefits',
#  108: 'best',
#  109: 'better',
#  110: 'big',
#  111: 'bit',
#  112: 'black',
#  113: 'blend',
#  114: 'blog',
#  115: 'blood',
#  116: 'blue',
#  117: 'board',
#  118: 'body',
#  119: 'boil',
#  120: 'book',
#  121: 'bought',
#  122: 'bowl',
#  123: 'box',
#  124: 'brain',
#  125: 'bread',
#  126: 'break',
#  127: 'breakfast',
#  128: 'breast',
#  129: 'bring',
#  130: 'broccoli',
#  131: 'brown',
#  132: 'brownies',
#  133: 'business',
#  134: 'butter',
#  135: 'buy',
#  136: 'buzz',
#  137: 'cake',
#  138: 'cakes',
#  139: 'california',
#  140: 'called',
#  141: 'calories',
#  142: 'came',
#  143: 'campaign',
#  144: 'cancer',
#  145: 'candy',
#  146: 'car',
#  147: 'caramel',
#  148: 'care',
#  149: 'case',
#  150: 'category',
#  151: 'cause',
#  152: 'cells',
#  153: 'center',
#  154: 'certain',
#  155: 'chance',
#  156: 'change',
#  157: 'check',
#  158: 'cheddar',
#  159: 'cheese',
#  160: 'cheesecake',
#  161: 'chef',
#  162: 'chicken',
#  163: 'child',
#  164: 'children',
#  165: 'chili',
#  166: 'chinese',
#  167: 'chip',
#  168: 'chips',
#  169: 'chocolate',
#  170: 'choice',
#  171: 'cholesterol',
#  172: 'choose',
#  173: 'chopped',
#  174: 'christmas',
#  175: 'cinnamon',
#  176: 'city',
#  177: 'class',
#  178: 'classic',
#  179: 'clean',
#  180: 'clear',
#  181: 'click',
#  182: 'close',
#  183: 'clothing',
#  184: 'cloves',
#  185: 'coat',
#  186: 'cocoa',
#  187: 'coconut',
#  188: 'coffee',
#  189: 'cold',
#  190: 'collection',
#  191: 'college',
#  192: 'color',
#  193: 'com',
#  194: 'combination',
#  195: 'combine',
#  196: 'combined',
#  197: 'come',
#  198: 'comes',
#  199: 'coming',
#  200: 'comment',
#  201: 'comments',
#  202: 'common',
#  203: 'community',
#  204: 'company',
#  205: 'complete',
#  206: 'completely',
#  207: 'computer',
#  208: 'concept',
#  209: 'container',
#  210: 'content',
#  211: 'continue',
#  212: 'control',
#  213: 'cook',
#  214: 'cooked',
#  215: 'cookie',
#  216: 'cookies',
#  217: 'cooking',
#  218: 'cool',
#  219: 'corn',
#  220: 'cost',
#  221: 'couldn',
#  222: 'country',
#  223: 'couple',
#  224: 'course',
#  225: 'cover',
#  226: 'covered',
#  227: 'cream',
#  228: 'creamy',
#  229: 'create',
#  230: 'created',
#  231: 'crisp',
#  232: 'crumbs',
#  233: 'crust',
#  234: 'culture',
#  235: 'cup',
#  236: 'cupcake',
#  237: 'cupcakes',
#  238: 'cups',
#  239: 'cut',
#  240: 'daily',
#  241: 'damascus',
#  242: 'dark',
#  243: 'data',
#  244: 'date',
#  245: 'day',
#  246: 'days',
#  247: 'deal',
#  248: 'death',
#  249: 'december',
#  250: 'decided',
#  251: 'deep',
#  252: 'definitely',
#  253: 'degrees',
#  254: 'delicious',
#  255: 'design',
#  256: 'designed',
#  257: 'dessert',
#  258: 'desserts',
#  259: 'did',
#  260: 'didn',
#  261: 'diet',
#  262: 'different',
#  263: 'dinner',
#  264: 'dip',
#  265: 'directions',
#  266: 'disease',
#  267: 'dish',
#  268: 'dishes',
#  269: 'display',
#  270: 'div',
#  271: 'does',
#  272: 'doesn',
#  273: 'dog',
#  274: 'doing',
#  275: 'don',
#  276: 'double',
#  277: 'dough',
#  278: 'dr',
#  279: 'dress',
#  280: 'dried',
#  281: 'drink',
#  282: 'drinking',
#  283: 'drop',
#  284: 'drug',
#  285: 'dry',
#  286: 'early',
#  287: 'easier',
#  288: 'easily',
#  289: 'easy',
#  290: 'eat',
#  291: 'eating',
#  292: 'edges',
#  293: 'effect',
#  294: 'effects',
#  295: 'egg',
#  296: 'eggs',
#  297: 'electric',
#  298: 'email',
#  299: 'end',
#  300: 'energy',
#  301: 'enjoy',
#  302: 'entire',
#  303: 'especially',
#  304: 'evenly',
#  305: 'event',
#  306: 'exactly',
#  307: 'example',
#  308: 'exercise',
#  309: 'experience',
#  310: 'extra',
#  311: 'extract',
#  312: 'eye',
#  313: 'eyes',
#  314: 'face',
#  315: 'facebook',
#  316: 'fact',
#  317: 'fall',
#  318: 'false',
#  319: 'family',
#  320: 'fan',
#  321: 'fans',
#  322: 'far',
#  323: 'fashion',
#  324: 'fast',
#  325: 'fat',
#  326: 'favorite',
#  327: 'features',
#  328: 'february',
#  329: 'feel',
#  330: 'feeling',
#  331: 'feet',
#  332: 'fiber',
#  333: 'field',
#  334: 'filled',
#  335: 'filling',
#  336: 'finally',
#  337: 'fine',
#  338: 'firm',
#  339: 'fish',
#  340: 'fit',
#  341: 'fitness',
#  342: 'flashvars',
#  343: 'flat',
#  344: 'flavor',
#  345: 'flavors',
#  346: 'flour',
#  347: 'foil',
#  348: 'fold',
#  349: 'follow',
#  350: 'following',
#  351: 'food',
#  352: 'foods',
#  353: 'football',
#  354: 'form',
#  355: 'free',
#  356: 'freezer',
#  357: 'french',
#  358: 'fresh',
#  359: 'fridge',
#  360: 'fried',
#  361: 'friend',
#  362: 'friends',
#  363: 'frosting',
#  364: 'frozen',
#  365: 'fruit',
#  366: 'fruits',
#  367: 'fry',
#  368: 'fun',
#  369: 'function',
#  370: 'funny',
#  371: 'future',
#  372: 'game',
#  373: 'games',
#  374: 'garlic',
#  375: 'gently',
#  376: 'gets',
#  377: 'getting',
#  378: 'ginger',
#  379: 'girl',
#  380: 'given',
#  381: 'gives',
#  382: 'glass',
#  383: 'goes',
#  384: 'going',
#  385: 'gold',
#  386: 'golden',
#  387: 'good',
#  388: 'google',
#  389: 'got',
#  390: 'grated',
#  391: 'great',
#  392: 'green',
#  393: 'grill',
#  394: 'grilled',
#  395: 'ground',
#  396: 'group',
#  397: 'guide',
#  398: 'guy',
#  399: 'hair',
#  400: 'half',
#  401: 'hand',
#  402: 'hands',
#  403: 'happy',
#  404: 'hard',
#  405: 'having',
#  406: 'head',
#  407: 'health',
#  408: 'healthy',
#  409: 'heart',
#  410: 'heat',
#  411: 'heavy',
#  412: 'height',
#  413: 'help',
#  414: 'helps',
#  415: 'herbs',
#  416: 'high',
#  417: 'history',
#  418: 'hit',
#  419: 'hold',
#  420: 'holiday',
#  421: 'home',
#  422: 'homemade',
#  423: 'honey',
#  424: 'hope',
#  425: 'hot',
#  426: 'hour',
#  427: 'hours',
#  428: 'house',
#  429: 'href',
#  430: 'http',
#  431: 'huge',
#  432: 'human',
#  433: 'ice',
#  434: 'idea',
#  435: 'ideas',
#  436: 'image',
#  437: 'images',
#  438: 'immediately',
#  439: 'important',
#  440: 'improve',
#  441: 'inch',
#  442: 'inches',
#  443: 'include',
#  444: 'including',
#  445: 'increase',
#  446: 'industry',
#  447: 'information',
#  448: 'ingredients',
#  449: 'inside',
#  450: 'inspired',
#  451: 'instead',
#  452: 'instructions',
#  453: 'interesting',
#  454: 'international',
#  455: 'internet',
#  456: 'iphone',
#  457: 'isn',
#  458: 'issue',
#  459: 'italian',
#  460: 'items',
#  461: 'january',
#  462: 'job',
#  463: 'jpg',
#  464: 'juice',
#  465: 'july',
#  466: 'june',
#  467: 'just',
#  468: 'key',
#  469: 'kids',
#  470: 'kind',
#  471: 'kitchen',
#  472: 'knew',
#  473: 'knife',
#  474: 'know',
#  475: 'known',
#  476: 'la',
#  477: 'large',
#  478: 'later',
#  479: 'latest',
#  480: 'layer',
#  481: 'lead',
#  482: 'learn',
#  483: 'leave',
#  484: 'leaves',
#  485: 'left',
#  486: 'lemon',
#  487: 'let',
#  488: 'level',
#  489: 'levels',
#  490: 'life',
#  491: 'light',
#  492: 'lightly',
#  493: 'like',
#  494: 'likely',
#  495: 'lime',
#  496: 'line',
#  497: 'link',
#  498: 'liquid',
#  499: 'list',
#  500: 'little',
#  501: 'live',
#  502: 'living',
#  503: 'll',
#  504: 'local',
#  505: 'london',
#  506: 'long',
#  507: 'longer',
#  508: 'look',
#  509: 'looking',
#  510: 'looks',
#  511: 'lose',
#  512: 'loss',
#  513: 'lost',
#  514: 'lot',
#  515: 'lots',
#  516: 'love',
#  517: 'low',
#  518: 'lower',
#  519: 'lunch',
#  520: 'magazine',
#  521: 'main',
#  522: 'major',
#  523: 'make',
#  524: 'makes',
#  525: 'making',
#  526: 'man',
#  527: 'march',
#  528: 'market',
#  529: 'matter',
#  530: 'maybe',
#  531: 'meal',
#  532: 'meals',
#  533: 'mean',
#  534: 'means',
#  535: 'meat',
#  536: 'media',
#  537: 'medical',
#  538: 'medicine',
#  539: 'medium',
#  540: 'melt',
#  541: 'melted',
#  542: 'memory',
#  543: 'men',
#  544: 'method',
#  545: 'microwave',
#  546: 'middle',
#  547: 'milk',
#  548: 'million',
#  549: 'mind',
#  550: 'mini',
#  551: 'minute',
#  552: 'minutes',
#  553: 'mix',
#  554: 'mixed',
#  555: 'mixer',
#  556: 'mixing',
#  557: 'mixture',
#  558: 'model',
#  559: 'models',
#  560: 'mom',
#  561: 'moment',
#  562: 'money',
#  563: 'month',
#  564: 'months',
#  565: 'morning',
#  566: 'mother',
#  567: 'mouth',
#  568: 'muffin',
#  569: 'muscle',
#  570: 'muscles',
#  571: 'mushrooms',
#  572: 'music',
#  573: 'national',
#  574: 'natural',
#  575: 'need',
#  576: 'needed',
#  577: 'needs',
#  578: 'network',
#  579: 'new',
#  580: 'news',
#  581: 'nfl',
#  582: 'nice',
#  583: 'night',
#  584: 'non',
#  585: 'normal',
#  586: 'note',
#  587: 'november',
#  588: 'number',
#  589: 'nutella',
#  590: 'nutrition',
#  591: 'nuts',
#  592: 'october',
#  593: 'offer',
#  594: 'offers',
#  595: 'office',
#  596: 'oh',
#  597: 'oil',
#  598: 'old',
#  599: 'olive',
#  600: 'olympic',
#  601: 'olympics',
#  602: 'ones',
#  603: 'onion',
#  604: 'onions',
#  605: 'online',
#  606: 'open',
#  607: 'optional',
#  608: 'orange',
#  609: 'order',
#  610: 'organic',
#  611: 'original',
#  612: 'ounces',
#  613: 'outside',
#  614: 'oven',
#  615: 'oz',
#  616: 'package',
#  617: 'page',
#  618: 'pain',
#  619: 'pan',
#  620: 'paper',
#  621: 'parchment',
#  622: 'parents',
#  623: 'parmesan',
#  624: 'party',
#  625: 'past',
#  626: 'pasta',
#  627: 'pastry',
#  628: 'peanut',
#  629: 'people',
#  630: 'pepper',
#  631: 'peppers',
#  632: 'percent',
#  633: 'perfect',
#  634: 'person',
#  635: 'personal',
#  636: 'phone',
#  637: 'photo',
#  638: 'photography',
#  639: 'photos',
#  640: 'physical',
#  641: 'pick',
#  642: 'picture',
#  643: 'pictures',
#  644: 'pie',
#  645: 'piece',
#  646: 'pieces',
#  647: 'pink',
#  648: 'pizza',
#  649: 'place',
#  650: 'plan',
#  651: 'plastic',
#  652: 'plate',
#  653: 'play',
#  654: 'player',
#  655: 'plus',
#  656: 'pm',
#  657: 'point',
#  658: 'police',
#  659: 'pop',
#  660: 'popular',
#  661: 'pork',
#  662: 'position',
#  663: 'possible',
#  664: 'post',
#  665: 'posted',
#  666: 'posts',
#  667: 'pot',
#  668: 'potato',
#  669: 'potatoes',
#  670: 'pound',
#  671: 'pounds',
#  672: 'pour',
#  673: 'powder',
#  674: 'powdered',
#  675: 'power',
#  676: 'preheat',
#  677: 'prepare',
#  678: 'prepared',
#  679: 'press',
#  680: 'pressure',
#  681: 'pretty',
#  682: 'prevent',
#  683: 'print',
#  684: 'probably',
#  685: 'problem',
#  686: 'problems',
#  687: 'process',
#  688: 'processor',
#  689: 'produce',
#  690: 'product',
#  691: 'products',
#  692: 'program',
#  693: 'project',
#  694: 'protein',
#  695: 'provide',
#  696: 'public',
#  697: 'published',
#  698: 'pull',
#  699: 'pumpkin',
#  700: 'purpose',
#  701: 'quality',
#  702: 'question',
#  703: 'quick',
#  704: 'quickly',
#  705: 'quite',
#  706: 'rack',
#  707: 'raw',
#  708: 'read',
#  709: 'reading',
#  710: 'ready',
#  711: 'real',
#  712: 'really',
#  713: 'reason',
#  714: 'recent',
#  715: 'recently',
#  716: 'recipe',
#  717: 'recipes',
#  718: 'red',
#  719: 'reduce',
#  720: 'refrigerator',
#  721: 'regular',
#  722: 'related',
#  723: 'remaining',
#  724: 'remember',
#  725: 'remove',
#  726: 'repeat',
#  727: 'report',
#  728: 'research',
#  729: 'researchers',
#  730: 'rest',
#  731: 'restaurant',
#  732: 'result',
#  733: 'results',
#  734: 'return',
#  735: 'review',
#  736: 'rice',
#  737: 'rich',
#  738: 'right',
#  739: 'rise',
#  740: 'risk',
#  741: 'roasted',
#  742: 'roll',
#  743: 'rolls',
#  744: 'room',
#  745: 'round',
#  746: 'run',
#  747: 'running',
#  748: 'safe',
#  749: 'said',
#  750: 'salad',
#  751: 'salt',
#  752: 'san',
#  753: 'sandwich',
#  754: 'sauce',
#  755: 'saucepan',
#  756: 'save',
#  757: 'saw',
#  758: 'say',
#  759: 'says',
#  760: 'school',
#  761: 'science',
#  762: 'search',
#  763: 'season',
#  764: 'second',
#  765: 'seconds',
#  766: 'seeds',
#  767: 'seen',
#  768: 'self',
#  769: 'september',
#  770: 'serve',
#  771: 'served',
#  772: 'serving',
#  773: 'set',
#  774: 'sex',
#  775: 'shape',
#  776: 'share',
#  777: 'sheet',
#  778: 'shoes',
#  779: 'shop',
#  780: 'short',
#  781: 'shows',
#  782: 'shredded',
#  783: 'shrimp',
#  784: 'si',
#  785: 'sides',
#  786: 'sign',
#  787: 'similar',
#  788: 'simmer',
#  789: 'simple',
#  790: 'simply',
#  791: 'single',
#  792: 'sit',
#  793: 'site',
#  794: 'size',
#  795: 'skillet',
#  796: 'skin',
#  797: 'sleep',
#  798: 'slice',
#  799: 'sliced',
#  800: 'slices',
#  801: 'slightly',
#  802: 'slow',
#  803: 'slowly',
#  804: 'small',
#  805: 'smooth',
#  806: 'snack',
#  807: 'social',
#  808: 'soda',
#  809: 'soft',
#  810: 'soon',
#  811: 'soup',
#  812: 'sour',
#  813: 'source',
#  814: 'space',
#  815: 'special',
#  816: 'speed',
#  817: 'spend',
#  818: 'spice',
#  819: 'spinach',
#  820: 'spoon',
#  821: 'sport',
#  822: 'sports',
#  823: 'spray',
#  824: 'spread',
#  825: 'spring',
#  826: 'sprinkle',
#  827: 'stand',
#  828: 'star',
#  829: 'start',
#  830: 'started',
#  831: 'starting',
#  832: 'state',
#  833: 'states',
#  834: 'static',
#  835: 'stay',
#  836: 'steak',
#  837: 'step',
#  838: 'stick',
#  839: 'stir',
#  840: 'stirring',
#  841: 'stop',
#  842: 'store',
#  843: 'story',
#  844: 'straight',
#  845: 'strawberries',
#  846: 'strawberry',
#  847: 'street',
#  848: 'stress',
#  849: 'strong',
#  850: 'studies',
#  851: 'study',
#  852: 'stuff',
#  853: 'style',
#  854: 'sugar',
#  855: 'summer',
#  856: 'sun',
#  857: 'super',
#  858: 'support',
#  859: 'sure',
#  860: 'surface',
#  861: 'sweet',
#  862: 'swimsuit',
#  863: 'syrup',
#  864: 'table',
#  865: 'tablespoon',
#  866: 'tablespoons',
#  867: 'taken',
#  868: 'takes',
#  869: 'taking',
#  870: 'talk',
#  871: 'taste',
#  872: 'tasty',
#  873: 'tbsp',
#  874: 'tea',
#  875: 'team',
#  876: 'teaspoon',
#  877: 'teaspoons',
#  878: 'tech',
#  879: 'technology',
#  880: 'tell',
#  881: 'temperature',
#  882: 'tender',
#  883: 'term',
#  884: 'test',
#  885: 'text',
#  886: 'texture',
#  887: 'thank',
#  888: 'thanks',
#  889: 'thing',
#  890: 'things',
#  891: 'think',
#  892: 'thinking',
#  893: 'thought',
#  894: 'throw',
#  895: 'time',
#  896: 'times',
#  897: 'tip',
#  898: 'tips',
#  899: 'today',
#  900: 'told',
#  901: 'tomato',
#  902: 'tomatoes',
#  903: 'took',
#  904: 'topping',
#  905: 'toss',
#  906: 'total',
#  907: 'touch',
#  908: 'track',
#  909: 'traditional',
#  910: 'training',
#  911: 'transfer',
#  912: 'treat',
#  913: 'treatment',
#  914: 'tried',
#  915: 'true',
#  916: 'try',
#  917: 'trying',
#  918: 'tsp',
#  919: 'turkey',
#  920: 'turn',
#  921: 'turned',
#  922: 'tv',
#  923: 'twitter',
#  924: 'type',
#  925: 'types',
#  926: 'united',
#  927: 'university',
#  928: 'unsalted',
#  929: 'url',
#  930: 'use',
#  931: 'used',
#  932: 'user',
#  933: 'username',
#  934: 'users',
#  935: 'uses',
#  936: 'using',
#  937: 'usually',
#  938: 'vanilla',
#  939: 'var',
#  940: 'variety',
#  941: 've',
#  942: 'vegan',
#  943: 'vegetable',
#  944: 'vegetables',
#  945: 'vegetarian',
#  946: 'version',
#  947: 'video',
#  948: 'videos',
#  949: 'view',
#  950: 'vinegar',
#  951: 'vitamin',
#  952: 'wait',
#  953: 'want',
#  954: 'wanted',
#  955: 'warm',
#  956: 'wasn',
#  957: 'watch',
#  958: 'water',
#  959: 'way',
#  960: 'ways',
#  961: 'wear',
#  962: 'web',
#  963: 'website',
#  964: 'week',
#  965: 'weeks',
#  966: 'weight',
#  967: 'went',
#  968: 'wheat',
#  969: 'whipped',
#  970: 'whisk',
#  971: 'white',
#  972: 'whites',
#  973: 'wide',
#  974: 'width',
#  975: 'win',
#  976: 'wine',
#  977: 'winter',
#  978: 'woman',
#  979: 'women',
#  980: 'won',
#  981: 'wonderful',
#  982: 'words',
#  983: 'work',
#  984: 'working',
#  985: 'workout',
#  986: 'works',
#  987: 'world',
#  988: 'worth',
#  989: 'wrap',
#  990: 'wrong',
#  991: 'www',
#  992: 'year',
#  993: 'years',
#  994: 'yeast',
#  995: 'yellow',
#  996: 'yes',
#  997: 'yogurt',
#  998: 'york',
#  999: 'young'}

# %%
from gensim.models.ldamodel import LdaModel
from gensim.matutils import Sparse2Corpus
corpus = Sparse2Corpus(X, documents_columns = False)
lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=15)

# %%
num_topics = 15
num_words_per_topic = 5
for ti, topic in enumerate(lda_model.show_topics(num_topics = num_topics, num_words =num_words_per_topic)):
    print ("Topic: %d" % (ti))
    print (topic)
# Out:
# Topic: 0
# (0, '0.031*"news" + 0.021*"10" + 0.017*"12" + 0.016*"clothing" + 0.016*"fashion"')
#
# Topic: 1
# (1, '0.030*"apple" + 0.016*"iphone" + 0.014*"new" + 0.014*"use" + 0.012*"app"')
#
# Topic: 2
# (2, '0.033*"recipes" + 0.024*"recipe" + 0.023*"food" + 0.022*"bacon" + 0.014*"make"')
#
# Topic: 3
# (3, '0.013*"minutes" + 0.012*"make" + 0.012*"like" + 0.012*"add" + 0.011*"just"')
#
# Topic: 4
# (4, '0.016*"egg" + 0.015*"eggs" + 0.013*"baking" + 0.013*"dough" + 0.012*"sheet"')
#
# Topic: 5
# (5, '0.020*"food" + 0.017*"health" + 0.016*"foods" + 0.013*"cancer" + 0.011*"2009"')
#
# Topic: 6
# (6, '0.021*"cup" + 0.021*"chicken" + 0.016*"add" + 0.015*"oil" + 0.014*"bread"')
#
# Topic: 7
# (7, '0.027*"chocolate" + 0.021*"cup" + 0.020*"butter" + 0.016*"sugar" + 0.016*"cake"')
#
# Topic: 8
# (8, '0.091*"com" + 0.077*"http" + 0.068*"www" + 0.064*"flashvars" + 0.048*"online"')
#
# Topic: 9
# (9, '0.013*"just" + 0.013*"body" + 0.013*"make" + 0.012*"like" + 0.011*"don"')
#
# Topic: 10
# (10, '0.031*"image" + 0.029*"2011" + 0.028*"images" + 0.024*"link" + 0.021*"small"')
#
# Topic: 11
# (11, '0.027*"sleep" + 0.023*"health" + 0.018*"brain" + 0.013*"information" + 0.012*"people"')
#
# Topic: 12
# (12, '0.012*"like" + 0.012*"just" + 0.011*"new" + 0.011*"time" + 0.009*"people"')
#
# Topic: 13
# (13, '0.032*"food" + 0.032*"raw" + 0.021*"chocolate" + 0.018*"sugar" + 0.015*"milk"')
#
# Topic: 14
# (14, '0.013*"pumpkin" + 0.013*"soup" + 0.012*"recipe" + 0.011*"like" + 0.010*"olympics"')

# %%
from gensim.models.word2vec import Word2Vec
# Setup the body text
text = data.body.dropna().map(lambda x: x.split())
model = Word2Vec(text, size=100, window=5, min_count=5, workers=4)

# %%
model.most_similar(positive=['cookie', 'brownie'])
# Out:
# [('cupcake', 0.9171594977378845),
#  ('pie', 0.8636468052864075),
#  ('candy', 0.8458801507949829),
#  ('mini', 0.8321999311447144),
#  ('pancake', 0.831588625907898),
#  ('crust', 0.8289937376976013),
#  ('cake', 0.823381781578064),
#  ('granola', 0.8211164474487305),
#  ('buttercream', 0.8184462189674377),
#  ('tart', 0.8157598972320557)]

# %%
# Loading the tweet data
filename = '../dataset/captured-tweets.txt'
tweets = []
for tweet in codecs.open(filename, 'r', encoding="utf-8"):
    tweets.append(tweet)
# Setting up spacy
nlp_toolkit = English()

# %%
tweet_df=pd.DataFrame({'tweet':tweets})
tweet_df.head()
# Out:
#                                                tweet
# 0  I made a(n) Small Tourmaline in Paradise Islan...
# 1  RT @PURELOVEBEAST: -เช็ครายละเอียด- 27th BIRTH...
# 2                          https://t.co/EOfBdVQUfO\n
# 3                      @ViGiGu google it :) simple\n
# 4           nerd ass girl  https://t.co/T7kDirxPEL\n

# %% [markdown]
# ## Exercise 1a
#
# Write a function that can take a take a sentence parsed by `spacy` and identify if it mentions a company named 'Google'. Remember, `spacy` can find entities and codes them as `ORG` if they are a company. Look at the slides for class 13 if you need a hint:
#
# ### Bonus (1b)
#
# Parameterize the company name so that the function works for any company.

# %%
def mentions_company(parsed):
    parsed = nlp_toolkit(parsed)
    # Return True if the sentence contains an organization and that organization is Google
#     if(any([word.ent_type_ == 'ORG' for word in parsed])):
    if any([str(word)=='Google' for word in parsed]):
            return True
    return False
# 1b
def mentions_company(parsed, company='Google'):
#     Your code here
    parsed = nlp_toolkit(parsed)
    if any([str(word)==company for word in parsed]):
            return True
    return False
print (tweet_df[tweet_df.tweet.map(lambda x: mentions_company(x, 'Google'))])
# Out:
#                                                   tweet
# 8                          Google Play Gift Card Code\n
# 9     Claim your Google Play Gift Card Code... https...
# 13    King of dark fantasy. Summon today. App Store:...
# 14    King of dark fantasy. Summon today. App Store:...
# 16    I've entered to win a Google Nexus 6P from  ! ...
# 18    RT @kamcb29: I've entered to win a Google Nexu...
# 20    I LOVE your Google plus page with the other gi...
# 21    After I've Google &amp; read a ton of articles...
# 23    RT @ShowerThoughtts: Apple has "air", Amazon h...
# 24    -Looks up on Google 'MikexJeremy' secretly- &l...
# 25    RT @_silentbent_: Go support @dadeputy single ...
# 29    Ever wanted to become a Google Small Business ...
# 31    Top Android Apps (without all the games) revea...
# 33    https://t.co/0ElEQm917Q How To Increase Blog T...
# 35                        Europe could produce a Fac...
# 38                        Europe could produce a Fac...
# 40    New post: Google Knowledge Graph Optimization ...
# 41    Anyone else spend the entire time driving tryi...
# 43    Google, you've failed me for the first time! W...
# 48                                    Google #Team2PM\n
# 53    RT https://t.co/s2HOfLUV2t #Google '#Android N...
# 57    @ImbruedJoint Hector had softly tilted his hea...
# 60    Google Knowledge Graph Optimization Strategies...
# 61    LebanonHashtag: RT probrandz: #Facebook Open S...
# 63    @r0thejan Earn free Google Play and many more ...
# 64    KalGuntuku: RT bunnymiilk "RT 30seclovelive: [...
# 65    RT @FortuneMagazine: Here’s how Google is taki...
# 67    shenbrood: What's your greatest #digitalmarket...
# 68    https://t.co/tkiiygFXRd What each state #Googl...
# 70    Europe could produce a Facebook - and the Goog...
# ...                                                 ...
# 3182  RT @Allanimeinforma: Top 10 searched keywords ...
# 3186  RT @Scribessy: Tips to Improve Your Business w...
# 3188  Google got its name by accident. The founders ...
# 3190  11 Google tricks that will change the way you ...
# 3191  RT @mindglobal: Like it or not, v wil get more...
# 3193  RT @RetiredFilth: Gotta set a Google calendar ...
# 3195  Come join me in an epic adventure. Invite ID: ...
# 3198  King of dark fantasy. Summon today. App Store:...
# 3199  King of dark fantasy. Summon today. App Store:...
# 3203  RT @mindglobal: Like it or not, v wil get more...
# 3204  King of dark fantasy. Summon today. App Store:...
# 3205  RT @Nickelodeon_AU: Download our app #NickPlay...
# 3206  @twitersgoodboy @IceBergMama Google emoji are ...
# 3207  Google Dorks SQLi Colleciton - https://t.co/1k...
# 3208     RT @GoogleInvestor: Google Up +1.6% for Week\n
# 3212  New Google Chat App Could Destroy Facebook Mes...
# 3213  Amateur Archaeologist + Google Earth = Bronze ...
# 3214  I added a video to a @YouTube playlist https:/...
# 3216  King of dark fantasy. Summon today. App Store:...
# 3217  RT @ramprasad_c: .@sardesairajdeep It takes 58...
# 3219  King of dark fantasy. Summon today. App Store:...
# 3220  RT @GoogleInvestor: Google Up +$247.35 &amp; +...
# 3222  King of dark fantasy. Summon today. App Store:...
# 3223  King of dark fantasy. Summon today. App Store:...
# 3226  New Event Now On. Get New Rank S Monsters. App...
# 3228  Top Android Apps (without all the games) revea...
# 3230  RT @TechnoBuffalo: Nexus owners report sync is...
# 3979  #Google Taking Aim at Uber in 2016 https://t.c...
# 4807  Microsoft joins Google and Facebook with warni...
# 4898  Predictions 2016: Apple, Tesla, Google, Medium...
#
# [1353 rows x 1 columns]

# %% [markdown]
# ## Exercise 1c
#
# Write a function that can take a sentence parsed by `spacy`
# and return the verbs of the sentence (preferably lemmatized)

# %%
def get_actions(parsed):
    actions = []
    # Your code here
    return actions

# %% [markdown]
# ## Exercise 1d
# For each tweet, parse it using spacy and print it out if the tweet has 'release' or 'announce' as a verb. You'll need to use your `mentions_company` and `get_actions` functions.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    if any([((word.lemma_ == 'release') or (word.lemma_=='announce')) for word in parsed]):
        print (tweet, "\n")
# Out:
# Google &amp; Ford rumored to announce partnership at CES https://t.co/zOgm1NjHhD https://t.co/Gzx81ujqVC
#
#
# Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/Qvmc34T5QA
#
#
# Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/GNmL0uw9xl
#
#
# Manzama Announces New Partnership With ClearView Social - IT News Online https://t.co/BWI94MWe6v
#
#
# Google's Project Ara Spiral is expected to be released next year January https://t.co/prycPMuGsG
#
#
# #Lenovo And #Google To Officially Announce #ProjectTango On January 7 At CES https://t.co/04seCBKv16
#
#
# EXO Line update about the duet song 'Dream' sung by Baekhyun and Suzy. Release on 7 Ja https://t.co/6Gy1Ga9A2S https://t.co/dbxm9S4FKd
#
#
# RT @GizmoChina: Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/GNmL0uw9xl
#
#
# Google and Ford to announce partnership on self-driving cars at CES - Fudzilla (blog) https://t.co/6woe56G22Q
#
#
# 10 lucky champs will be announced by 12:00 PM
#
#
# Moxian Inc. (MOXC) Boasts Rapid Corporate Growth along with a Strong ... - https://t.co/lIfEQPezuL (press release) https://t.co/mzkXrWttNK
#
#
# Google and Ford to announce partnership on self-driving cars at CES - Fudzilla (blog) https://t.co/4hERVJ4zZK
#
#
# #News NTSB releases photos showing El Faro in final resting place - Fox News https://t.co/d0BHmDgobJ Vía @Google
#
#
# Redesigned Google Glass published on FCC website: release date, Price and features - Tampa Bay Review https://t.co/Vdwr4afx3E www.GlassRoo…
#
#
# RT @nazirumikailu: Iran pressures Nigeria, demands the release of top Shia leader Ibrahim El-Zakzaky https://t.co/z5vVXQyxLN #BBCAfricaLive
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/TRshnC6sVU
#
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/SlvcQtk3vE
#
#
# RT @Vatescorp: #Sudan: Ministry of Foreign Affairs announced Khartoum has decided to sever diplomatic ties with #Iran https://t.co/ofQG8gtL…
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# Hhmmm. Iran claiming to have 'warned Nigeria' to release detained Shiite leader.... @afalli
#
#
# RT @KenGardner11: Arab allies are breaking diplomatic relations with Iran. Obama's response? Release $100 billion to Iran. The quintessenti…
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# RT @NEWS957: Saudi Arabia announces it is severing ties with Iran, Canada urging diplomacy https://t.co/7JE6dOHoQV
#
#
# Syria’s opposition wants a prisoner release ahead of negotiations later this month - Business Insider https://t.co/FDf23sW7Xi
#
#
# RT @UKRinUN: Press release on the occasion of presentation of credentials by PR of Ukraine @YelchenkoUN https://t.co/ykpEQruEIH https://t.c…
#
#
# Saudi Arabia Just Announced It Plans On Severing Ties With Iran after a Tumultuous Weekend https://t.co/ERj1bScAn5 via @ijdotcom
#
#
# RT @ahmed: Full transcript of press conference where Saudi FM @AdelAljubeir announced cutting diplomatic relations with Iran https://t.co/L…
#
#
# RT @Ebuka_Mbanefo: We have warned Nigeria to release ZakZaky - Islamic Republic Of Iran - https://t.co/7oBA1G4sYH
#
#
# RT @shinobi602: Kotaku also reports: Watch Dogs 2 to release later this year, takes place in San Francisco https://t.co/kDQeNHUJDf https://…
#
#
# #microsoft Microsoft announces ReCore for Windows 10: Back at E3, Microsoft announced... https://t.co/sHo5LXjWHn - https://t.co/SbRnFnWkny
#
#
# ReCore Is Coming To The PC: Microsoft has announced that Keiji Inafune’s new action adventure title, ReCore, w... https://t.co/KTCyiGvGUY
#
#
# RT @benz145: Wild prediction: Microsoft announces Oculus Rift support for the Xbox One sometime in 2016.
#
#
# RT @maryjofoley: As of Jan. 1 (as previously announced), Bing powers AOL’s web, mobile, and tablet search: https://t.co/mM1AKn6EMT

# %% [markdown]
# ## Exercise 1e
# Write a function that identifies countries - HINT: the entity label for countries is GPE (or GeoPolitical Entity)

# %%
def mentions_country(parsed, country):
    pass

# %% [markdown]
# ## Exercise 1f
#
# Re-run (d) to find country tweets that discuss 'Iran' announcing or releasing.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    if any([((word.lemma_ == 'release') or (word.lemma_=='announce')) for word in parsed]) and any([str(word)=='Iran'for word in parsed]):
        print (tweet, "\n")
# Out:
# RT @nazirumikailu: Iran pressures Nigeria, demands the release of top Shia leader Ibrahim El-Zakzaky https://t.co/z5vVXQyxLN #BBCAfricaLive
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/TRshnC6sVU
#
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/SlvcQtk3vE
#
#
# RT @Vatescorp: #Sudan: Ministry of Foreign Affairs announced Khartoum has decided to sever diplomatic ties with #Iran https://t.co/ofQG8gtL…
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# Hhmmm. Iran claiming to have 'warned Nigeria' to release detained Shiite leader.... @afalli
#
#
# RT @KenGardner11: Arab allies are breaking diplomatic relations with Iran. Obama's response? Release $100 billion to Iran. The quintessenti…
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# RT @NEWS957: Saudi Arabia announces it is severing ties with Iran, Canada urging diplomacy https://t.co/7JE6dOHoQV
#
#
# Saudi Arabia Just Announced It Plans On Severing Ties With Iran after a Tumultuous Weekend https://t.co/ERj1bScAn5 via @ijdotcom
#
#
# RT @ahmed: Full transcript of press conference where Saudi FM @AdelAljubeir announced cutting diplomatic relations with Iran https://t.co/L…
#
#
# RT @Ebuka_Mbanefo: We have warned Nigeria to release ZakZaky - Islamic Republic Of Iran - https://t.co/7oBA1G4sYH

# %% [markdown]
# ## Exercise 2
# Build a `word2vec` model of the tweets we have collected using `gensim`.
#
# ### Exercise 2a:
# First take the collection of tweets and tokenize them using spacy.
#
# * Think about how this should be done.
# * Should you only use upper-case or lower-case?
# * Should you remove punctuations or symbols?

# %%
text_split = [[x.text if x.pos != spacy.parts_of_speech.VERB else x.lemma_ 
                for x in nlp_toolkit(t)] for t in tweets]

# %% [markdown]
# ### Exercise 2b:
# Build a `word2vec` model.
# Test the window size as well - this is how many surrounding words need to be used to model a word. What do you think is appropriate for Twitter?

# %%
model = Word2Vec(text_split, size=100, window=4, min_count=5, workers=4)

# %% [markdown]
# ### Exercise 2c:
# Test your word2vec model with a few similarity functions.
# * Find words similar to 'Syria'.
# * Find words similar to 'war'.
# * Find words similar to "Iran".
# * Find words similar to 'Verizon'.

# %%
model.most_similar(positive=['Verizon'])
# Out:
# [('Xbox', 0.9995508193969727),
#  ('32', 0.9995402693748474),
#  ('GB', 0.9995343685150146),
#  ('3', 0.9994818568229675),
#  ('Unlocked', 0.9994698762893677),
#  ('16', 0.9994678497314453),
#  ('iPhone', 0.9994553923606873),
#  ('Microsoft', 0.9994542002677917),
#  ('without', 0.9994506239891052),
#  ('Black', 0.9994388818740845)]

# %% [markdown]
# # Exercise 2d
#
# Adjust the choices / parameters in (b) and (c) as necessary.

# %% [markdown]
# ## Exercise 3
#
# Filter tweets to those that mention 'Iran' or similar entities and 'war' or similar entities.
# * Do this using just spacy.
# * Do this using word2vec similarity scores.

# %%
# Using spacy
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %%
# Using word2vec similarity scores
for tweet in tweets[:200]:
    parsed = nlp_toolkit(tweet)
    pass
